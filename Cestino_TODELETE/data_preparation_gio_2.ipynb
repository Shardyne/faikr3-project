# %% [markdown]
# # Data preparation
#
# In this notebook we're going to analyze and modify the dataset we found in order to make it suitable for the Bayesian Network implementation in pgmpy.
#
# - [Patterns/Cleaning](#show-data-patterns-and-cleaning)
# - [Binning and encoding](#binning-and-encoding)
# - [Final result](#final-result)

# %% [markdown]
# ## Show data patterns and cleaning

# %%
import pandas as pd

df = pd.read_csv("./dataset_raw.csv").drop(labels=["id"], axis=1)
print(f"Shape: {df.shape}")
# df.head()
# Out:
# Shape: (27901, 17)

# %%
df.info()
print(f"Duplicates: {sum(df.duplicated())}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27901 non-null  object
#  1   Age                                    27901 non-null  float64
#  2   City                                   27901 non-null  object
#  3   Profession                             27901 non-null  object
#  4   Academic Pressure                      27901 non-null  float64
#  5   Work Pressure                          27901 non-null  float64
#  6   CGPA                                   27901 non-null  float64
#  7   Study Satisfaction                     27901 non-null  float64
#  8   Job Satisfaction                       27901 non-null  float64
#  9   Sleep Duration                         27901 non-null  object
#  10  Dietary Habits                         27901 non-null  object
#  11  Degree                                 27901 non-null  object
#  12  Have you ever had suicidal thoughts ?  27901 non-null  object
#  13  Work/Study Hours                       27901 non-null  float64
#  14  Financial Stress                       27898 non-null  float64
#  15  Family History of Mental Illness       27901 non-null  object
#  16  Depression                             27901 non-null  int64
# dtypes: float64(8), int64(1), object(8)
# memory usage: 3.6+ MB
# Duplicates: 0

# %% [markdown]
# As we can see many dtypes are not discrete (float64) as required from Bayesian Networks and we can see also many non numerical attributes (object). We'll have to make some bins and some encodings in order to overcome the problem.
#
# Moreover we can notice that the data itself has some null values in the "Financial Stress" attribute, we'll drop those samples.

# %%
df_notna = df.dropna()
print(f"Dropped {df.shape[0] - df_notna.shape[0]} rows with nulls")
# Out:
# Dropped 3 rows with nulls

# %% [markdown]
# Then we'll plot the data in order to see some useful patterns which could also help us improving the dataset quality.

# %%
from utils import plot_dataframe_columns
plot_dataframe_columns(df_notna)

# %%
tot = df_notna.shape[0]

working_students = df_notna[df_notna["Profession"]!="Student"].index.to_list()
print(f"There are {len(working_students)} working students ({len(working_students)/tot*100:.2f}%)")

pression_students = df_notna[df_notna["Work Pressure"]!=0].index.to_list()
print(f"There are {len(working_students)} work-pressed students ({len(pression_students)/tot*100:.2f}%)")

satisfied_students = df_notna[df_notna["Job Satisfaction"]!=0].index.to_list()
print(f"There are {len(satisfied_students)} work-satisfied students ({len(satisfied_students)/tot*100:.2f}%)")
# Out:
# There are 31 working students (0.11%)
# There are 31 work-pressed students (0.01%)
# There are 8 work-satisfied students (0.03%)

# %% [markdown]
# We can notice an interesting patter about work. It seems like indian students are not likely to be also workers. In fact we can notice that in "Profession" is almpst completely filled by students and also "Job Satisfcation" and "Work Pressure" shows 0 as predominant value as almost no one works.
#
# We tried to figure out an explanation for this phenomenon but we only faced online discussions about it.
#
# Given that, we decided to delete the 'work' variable from our domain so we'll drop "Job Satisfaction", "Work Pressure", "Profession" and all the students that also works.

# %%
df_cleaned = df_notna.drop(columns=["Profession", "Work Pressure", "Job Satisfaction"])
df_cleaned.drop(index=working_students, inplace=True)
df_cleaned.rename(columns={"Work/Study Hours" : "Study Hours"}, inplace=True)   # for coherence

print(f"New shape: {df_cleaned.shape}")
# Out:
# New shape: (27867, 14)

# %%
plot_dataframe_columns(df_cleaned[["Age", "City"]], figsize_base=(30, 5), bins=60, show_all_xticks=True)

# %%
threshold = 1 # % threshold over all the samples
city_counts = df_cleaned['City'].value_counts()
unpopular_cities = city_counts[city_counts < threshold/100*df_cleaned.shape[0]].index
students_in_unpopular_cities = df_cleaned[df_cleaned['City'].isin(unpopular_cities)].shape[0]
print(f"There are {students_in_unpopular_cities} students (the {100*students_in_unpopular_cities/df_cleaned.shape[0]:.2f}%) in unpopular cities (which are {len(unpopular_cities)})")

# 34 observed by plot
over_34_students = df_cleaned[df_cleaned['Age'] > 34].shape[0]
print(f"There are {over_34_students} students (the {100*over_34_students/df_cleaned.shape[0]:.2f}%) over 34 y/o")
# Out:
# There are 26 students (the 0.09%) in unpopular cities (which are 22)
# There are 49 students (the 0.18%) over 34 y/o

# %% [markdown]
# We can notice that "Age" and "City" has many values that are not very frequent and we will cope with them differently:
# - **Age**: we will keep the values but will have to consider the unbalancement by slightly modifying the classical binning of age in order to inspect the attribute more effectively.
# - **City**: the 22 unpoular cities were difficult to find online and so, considering their small amount of samples, we'll delete them.

# %%
unpop_city_idxs = df_cleaned[df_cleaned['City'].isin(unpopular_cities)].index.to_list()
df_cleaned.drop(index=unpop_city_idxs, inplace=True)
df_cleaned.reset_index(drop=True, inplace=True)     

print(f"New shape: {df_cleaned.shape}")

plot_dataframe_columns(df_cleaned)
# Out:
# New shape: (27841, 14)

# %% [markdown]
# ## Binning and encoding
#
# 1. [Gender](#gender)
# 2. [Age](#age)
# 3. [City](#city)
# 4. [Sleep Duration](#sleep-duration)
# 5. [Dietary Habits](#dietary-habits)
# 6. [Degree](#degree)
# 7. [Suicidial Thougths](#suicidial-thougths)
# 8. [Study Hours](#study-hours)
# 9. [Mental Ilness](#mental-illness)

# %%
df_final = pd.DataFrame()
label_mappings = {}         # in order to keep track of encodings

# %% [markdown]
# ### Gender

# %%
from sklearn.preprocessing import LabelEncoder

label = "Gender"

encoder = LabelEncoder()
df_final[label] = encoder.fit_transform(df_cleaned[label])

label_mappings[label] = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))
label_mappings[label]
# Out:
# {'Female': np.int64(0), 'Male': np.int64(1)}

# %% [markdown]
# ### Age

# %% [markdown]
# We followed the [Provisional Guidelines on Standard International Age Classification](https://unstats.un.org/unsd/publication/seriesm/seriesm_74e.pdf), we chose the most detailed scale in order to better follow the distribution of "Age" values with mostly young individuals.

# %%
label = "Age"

min = df_cleaned[label].min()
great = df_cleaned[label].max()
print(f"The range is [{min},{great}]")

bins = [min-1, 24, 29, 34, great]  
bin_label = list(range(len(bins) - 1))  

df_final[label] = pd.cut(
    df_cleaned[label], 
    bins=bins, 
    labels=bin_label
).reset_index(drop=True).astype(int)

label_mappings[label] = {f"{int(bins[l])+1}-{int(bins[l+1])}": l for l in bin_label}
label_mappings[label]
# Out:
# The range is [18.0,59.0]
# {'18-24': 0, '25-29': 1, '30-34': 2, '35-59': 3}

# %% [markdown]
# ### City

# %% [markdown]
# Here we tried to obtain more information than the one we were given, since the city per se is a bit meaningless. Moreover is difficult to obtain data on the wellness of the individual starting from the city's economy as India is one of the most "unequal" country (as could be seen in the [World Inequality Report](https://wir2022.wid.world/www-site/uploads/2023/03/D_FINAL_WIL_RIM_RAPPORT_2303.pdf)). So we tried to merge the geographical information with an observation about [regional division and dsparity](https://www.researchgate.net/profile/Sivakumar-Iyyanar/publication/342590854_REGIONAL_DISPARITIES_AND_INDIAN_STATES_A_MACRO_LEVEL_STUDY/links/5efc5cee45851550508109f4/REGIONAL-DISPARITIES-AND-INDIAN-STATES-A-MACRO-LEVEL-STUDY.pdf) in order to group cities in macro areas and maybe infer somenthing about their level of social difficulty.

# %%
label='Regions'

# label create a new attribute with regions
label_city_regions={
    'Agra':'Central',
    'Ahmedabad':'Western',
    'Bangalore': 'Southern',
    'Bhopal':'Central',
    'Chennai':'Southern',
    'Delhi':'Northern',
    'Faridabad':'Northern',
    'Ghaziabad':'Central',
    'Hyderabad':'Southern',
    'Indore':'Central',
    'Jaipur':'Northern',
    'Kalyan':'Western',
    'Kanpur':'Central',
    'Kolkata':'Eastern',
    'Lucknow':'Central',
    'Ludhiana':'Northern',
    'Meerut':'Central',
    'Mumbai':'Western',
    'Nagpur':'Western',
    'Nashik':'Western',
    'Patna':'Eastern',
    'Pune':'Western',
    'Rajkot':'Western',
    'Srinagar':'Northern',
    'Surat':'Western',
    'Thane':'Western',
    'Vadodara':'Western',
    'Varanasi':'Central',
    'Vasai-Virar':'Western',
    'Visakhapatnam':'Southern',
}

df_cleaned[label]=df_cleaned['City'].map(label_city_regions)

regions=df_cleaned[label].unique().tolist()
label_mappings[label] = {regions[l]: l for l in range(len(regions))}

df_final[label]=df_cleaned[label].map(label_mappings[label]).reset_index(drop=True)
label_mappings[label]
# Out:
# {'Southern': 0, 'Northern': 1, 'Central': 2, 'Western': 3, 'Eastern': 4}

# %% [markdown]
# ### CGPA

# %% [markdown]
# Then we followed the [guidelines of an indian university](https://www.suniv.ac.in/upload/UGC%20Guidelines.pdf) in order to decide the dimension of CGPA bins.

# %%
label = "CGPA"

min = df_cleaned[label].min()
great = df_cleaned[label].max()
print(f"The range is [{min},{great}]")

bins = [min-1, 3.9, 4.9, 5.9, 6.9, 7.9, 8.9, great]  
bin_label = list(range(len(bins) - 1))  

df_final[label] = pd.cut(
    df_cleaned[label], 
    bins=bins, 
    labels=bin_label
).reset_index(drop=True).astype(int)

label_mappings[label] = {f"{int(bins[l])+1}-{bins[l+1]}": l for l in bin_label}
label_mappings[label]
# Out:
# The range is [0.0,10.0]
# {'0-3.9': 0,
#  '4-4.9': 1,
#  '5-5.9': 2,
#  '6-6.9': 3,
#  '7-7.9': 4,
#  '8-8.9': 5,
#  '9-10.0': 6}

# %% [markdown]
# ### Sleep Duration

# %%
label = "Sleep Duration"

label_mappings[label] = {
    'Less than 5 hours': 0,
    '5-6 hours': 1,
    '7-8 hours': 2,
    'More than 8 hours': 3,
    'Others': 4
}

df_final[label] = df_cleaned[label].map(label_mappings[label]).reset_index(drop=True)
label_mappings[label]
# Out:
# {'Less than 5 hours': 0,
#  '5-6 hours': 1,
#  '7-8 hours': 2,
#  'More than 8 hours': 3,
#  'Others': 4}

# %% [markdown]
# ### Dietary Habits

# %%
label = "Dietary Habits"

label_mappings[label] = {
    'Unhealthy' : 0, 
    'Moderate' : 1, 
    'Healthy' : 2, 
    'Others' : 3
}

df_final[label] = df_cleaned[label].map(label_mappings[label]).reset_index(drop=True)
label_mappings[label]
# Out:
# {'Unhealthy': 0, 'Moderate': 1, 'Healthy': 2, 'Others': 3}

# %% [markdown]
# ### Degree

# %% [markdown]
# Similarly to the "City" case, also for the Degree we think that the single value is not that much important so we tried 2 different groupings.
#
# The first one is by the level of education (high school, barchelor, master, doctorate).
#
# The second one is by the macro-categoy of the degree (scientific, humanistic, ...)

# %%
from utils import decode_degree

# Grouping the degrees by the level of education
def get_degree_group(degree):
    degree_groups = {
        "High School Completion": {"Class 12"},
        "Undergraduate Degrees": {
            "B.Pharm", "BSc", "BA", "BCA", "B.Ed", "LLB", "BE", "BHM",
            "B.Com", "B.Arch", "B.Tech", "BBA"
        },
        "Postgraduate Degrees": {
            "M.Tech", "M.Ed", "MSc", "M.Pharm", "MCA", "MA", "MBA", "M.Com",
            "LLM", "ME", "MHM"
        },
        "Doctorate & Medical Degrees": {"PhD", "MD", "MBBS"},
        "Others": {"Others"}
    }
    
    for group, degrees in degree_groups.items():
        if degree in degrees:
            return group
    
    return "Unknown Group"

# Grouping the degrees by educational macro-categories
def get_degree_category(degree):
    degree_categories = {
        "Scientific & Technical": {
            "BSc", "MSc", "B.Tech", "M.Tech", "BE", "ME", "BCA", "MCA", 
            "B.Pharm", "M.Pharm", "B.Arch", "MBBS", "MD"
        },
        "Humanistic & Social Sciences": {
            "BA", "MA", "B.Ed", "M.Ed", "LLB", "LLM", "B.Com", "M.Com", "BBA", "MBA"
        },
        "Medical & Life Sciences": {
            "MBBS", "MD", "B.Pharm", "M.Pharm"
        },
        "Legal & Political Sciences": {
            "LLB", "LLM"
        },
        "Business & Economics": {
            "B.Com", "M.Com", "BBA", "MBA"
        },
        "Hospitality & Tourism": {
            "BHM", "MHM"
        },
        "Doctorate & Research": {
            "PhD"
        },
        "Others": {"Class 12", "Others"}
    }
    
    for category, degrees in degree_categories.items():
        if degree in degrees:
            return category
    
    return "Unknown Category"

# %%
label = "Education Level"

label_mappings[label] = {
    'High School Completion': 0,
    'Undergraduate Degrees': 1,
    'Postgraduate Degrees': 2,
    'Doctorate & Medical Degrees': 3,
    'Others': 4
}

df_final[label] = df_cleaned["Degree"] \
                    .map(get_degree_group) \
                    .map(label_mappings[label]).reset_index(drop=True)
label_mappings[label]
# Out:
# {'High School Completion': 0,
#  'Undergraduate Degrees': 1,
#  'Postgraduate Degrees': 2,
#  'Doctorate & Medical Degrees': 3,
#  'Others': 4}

# %%
label = "Education Category"

label_mappings[label] = {
    'Hospitality & Tourism': 0,
    'Humanistic & Social Sciences': 1,
    'Scientific & Technical': 2,
    'Doctorate & Research': 3,
    'Others': 4
}

df_final[label] = df_cleaned["Degree"] \
                    .map(get_degree_category) \
                    .map(label_mappings[label]).reset_index(drop=True)
label_mappings[label]
# Out:
# {'Hospitality & Tourism': 0,
#  'Humanistic & Social Sciences': 1,
#  'Scientific & Technical': 2,
#  'Doctorate & Research': 3,
#  'Others': 4}

# %% [markdown]
# ### Suicidal Thoughts

# %%
label = "Have you ever had suicidal thoughts ?"

encoder = LabelEncoder()
df_final[label] = encoder.fit_transform(df_cleaned[label])

label_mappings[label] = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))
label_mappings[label]
# Out:
# {'No': np.int64(0), 'Yes': np.int64(1)}

# %% [markdown]
# ### Study Hours

# %%
label = "Study Hours"

min_val = int(df_cleaned[label].min())
great_val = int(df_cleaned[label].max())
print(f"The range is [{min_val},{great_val}]")

# Each bin after 3h
bins = [*range(min_val, great_val + 1, 3)]  
bins[-1] += 1   # othervise the other is not considered
bin_label = list(range(len(bins) - 1))

df_final[label] = pd.cut(
    df_cleaned[label], 
    bins=bins, 
    labels=bin_label,
    right=False,  #[)
).reset_index(drop=True).astype(int)

label_mappings[label] = {f"{bins[l]}-{bins[l+1]-1}": l for l in bin_label}
label_mappings[label]
# Out:
# The range is [0,12]
# {'0-2': 0, '3-5': 1, '6-8': 2, '9-12': 3}

# %% [markdown]
# ### Mental Illness

# %%
label = "Family History of Mental Illness"

encoder = LabelEncoder()
df_final[label] = encoder.fit_transform(df_cleaned[label])

label_mappings[label] = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))
label_mappings[label]
# Out:
# {'No': np.int64(0), 'Yes': np.int64(1)}

# %% [markdown]
# ## Final Result

# %%
import pickle 
from utils import to_camel_case

# Add the remaining attributes
rem_attrs = ["Academic Pressure", "Study Satisfaction", "Financial Stress", "Depression"]
for attr in rem_attrs:
    df_final[attr] = df_cleaned[attr].copy().astype(int)
    
# Plot
plot_dataframe_columns(df_final, show_all_xticks=True)

# Convert in BayesianNetwork notation
df_final.columns = [to_camel_case(col) for col in df_final.columns] 
label_mappings = {to_camel_case(col):v for col,v in label_mappings.items()}

# Save the new dataset and its mapping
df_final.to_csv("dataset_final.csv", index=False)
with open("label_mappings.pkl", 'wb') as f: pickle.dump(label_mappings, f)

# %% [markdown]
# # Clustering

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import pdist, squareform

# Sample categorical dataset
data = {'Color': ['Red', 'Blue', 'Red', 'Green', 'Blue', 'Green'],
        'Size': ['Small', 'Large', 'Small', 'Small', 'Large', 'Large'],
        'Shape': ['Round', 'Square', 'Square', 'Round', 'Square', 'Round']}

df = pd.DataFrame(data)

# Step 1: One-Hot Encode the Categorical Data
encoder = OneHotEncoder( sparse_output=False,drop=None)
encoded_data = encoder.fit_transform(df)

# Step 2: Compute Hamming Distance Matrix
hamming_dist_matrix = squareform(pdist(encoded_data, metric='hamming'))

# Step 3: Apply Agglomerative Clustering
agg_clustering = AgglomerativeClustering(n_clusters=2, metric='precomputed', linkage='average')
clusters = agg_clustering.fit_predict(hamming_dist_matrix)
silhouette_avg = silhouette_score(hamming_dist_matrix, clusters, metric="precomputed")

# Add Cluster Labels to DataFrame
df['Cluster'] = clusters

# Print Results
print(df)
silhouette_avg
# Out:
#    Color   Size   Shape  Cluster
# 0    Red  Small   Round        0
# 1   Blue  Large  Square        1
# 2    Red  Small  Square        0
# 3  Green  Small   Round        0
# 4   Blue  Large  Square        1
# 5  Green  Large   Round        0
# np.float64(0.5185185185185185)

# %%
from kmodes.kmodes import KModes
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
result_acs = pd.DataFrame({'inertia':[],'k':[],'silhouette':[]})
hamming_dist_matrix = pairwise_distances(df_academic, metric='hamming')

for k in range(2,10):
    km = KModes(n_clusters=k, init="Huang", n_init=5, verbose=1)
    clusters = km.fit_predict(df_academic)  # Use original categorical dataset, NOT one-hot encoded
    result_acs.loc[len(result_acs)]=[km.cost_,k,silhouette_score(hamming_dist_matrix,clusters, metric='precomputed')]

fig, ax1 = plt.subplots(figsize=(8, 5))

ax1.plot(result_acs["k"], result_acs["inertia"], marker="o", color="blue", label="Inertia")
ax1.set_xlabel("Number of Clusters")
ax1.set_ylabel("Inertia", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")

ax2 = ax1.twinx()
ax2.plot(result_acs["k"], result_acs["silhouette"], marker="s", color="red", linestyle="dashed", label="Silhouette Score")
ax2.set_ylabel("Silhouette Score", color="red")
ax2.tick_params(axis="y", labelcolor="red")
ax2.set_ylim(0,1)

fig.suptitle("Elbow Method & Silhouette Score")
fig.tight_layout()
plt.show()
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 49402.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2428, cost: 46248.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 3584, cost: 47690.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 2357, cost: 48595.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 47794.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 3830, cost: 41563.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 43743.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 6119, cost: 41868.0
# Run 3, iteration: 2/100, moves: 2386, cost: 41868.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 43761.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 45717.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 40003.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2341, cost: 36600.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 2297, cost: 38485.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 38324.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 5804, cost: 37904.0
# Run 5, iteration: 2/100, moves: 349, cost: 37904.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 4001, cost: 35538.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 38033.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 5787, cost: 38728.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 38315.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 37354.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 33931.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 33952.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 35007.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 2044, cost: 33978.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 36037.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 4811, cost: 32965.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2867, cost: 31891.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 33418.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 3257, cost: 32167.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1799, cost: 31371.0
# Best run was number 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 30278.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 4891, cost: 30780.0
# Run 2, iteration: 2/100, moves: 921, cost: 30780.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1352, cost: 32169.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 32009.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 32309.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 30070.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 31603.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 28602.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 30098.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 3322, cost: 32242.0
# Best run was number 3

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.model_selection import ParameterGrid
parameters = {'n_clusters': range(2,6), 'linkage':['complete', 'average', 'single'],'metric':['precomputed']}, 
df_academic=df_final[['AcademicPressure','FinancialStress']]
pg = list(ParameterGrid(parameters))
result_ac = pd.DataFrame({'linkage':[],'k':[],'silhouette':[]})
encoder = OneHotEncoder(sparse_output=False,drop=None)
encoded_data = encoder.fit_transform(df_academic)
hamming_dist_matrix = squareform(pdist(encoded_data, metric='hamming'))
for i in range(len(pg)):
    df = pd.DataFrame(data)
# Step 1: One-Hot Encode the Categorical Data
    ac = AgglomerativeClustering(**(pg[i]))
    y_ac = ac.fit_predict(hamming_dist_matrix)
    result_ac.loc[len(result_ac)]=[pg[i]['linkage'],pg[i]['n_clusters'],silhouette_score(hamming_dist_matrix,y_ac, metric='precomputed')]

result_ac.sort_values(by='silhouette',ascending=False)
# Out:
#      linkage  k  silhouette
# 3   complete  5    0.552895
# 2   complete  4    0.443693
# 7    average  5    0.405616
# 6    average  4    0.373208
# 1   complete  3    0.341129
# 5    average  3    0.272998
# 0   complete  2    0.219395
# 4    average  2    0.201678
# 8     single  2    0.085917
# 9     single  3   -0.019210
# 10    single  4   -0.158406
# 11    single  5   -0.265668

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.model_selection import ParameterGrid
parameters = {'n_clusters': range(2,6), 'linkage':['average', 'complete', 'single'],'metric':['precomputed']}, 
df_academic=df_final[['StudySatisfaction','Cgpa','EducationLevel']]
pg = list(ParameterGrid(parameters))
result_ac = pd.DataFrame({'linkage':[],'k':[],'silhouette':[]})
encoder = OneHotEncoder(sparse_output=False,drop=None)
encoded_data = encoder.fit_transform(df_academic)
hamming_dist_matrix = squareform(pdist(encoded_data, metric='hamming'))
for i in range(len(pg)):
    df = pd.DataFrame(data)
# Step 1: One-Hot Encode the Categorical Data
    ac = AgglomerativeClustering(**(pg[i]))
    y_ac = ac.fit_predict(hamming_dist_matrix)
    result_ac.loc[len(result_ac)]=[pg[i]['linkage'],pg[i]['n_clusters'],silhouette_score(hamming_dist_matrix,y_ac, metric='precomputed')]

import matplotlib.pyplot as plt

# %%
def BIC_score(model, test_data):
    # Evaluate log-likelihood on test data
    
    log_likelihood = model.log_probability(test_data).sum()
    
    N = len(test_data)  # Number of data points
    
    k_latent = len(model.get_cpds())  # Number of parameters (CPDs)
    
    BIC_latent = -2 * log_likelihood + k_latent * np.log(N)

    return BIC_latent

# %%
result_ac.sort_values(by='silhouette',ascending=False)
# Out:
#      linkage  k  silhouette
# 3    average  5    0.358353
# 2    average  4    0.332092
# 0    average  2    0.260247
# 1    average  3    0.254314
# 8     single  2    0.064347
# 7   complete  5    0.057924
# 6   complete  4    0.032982
# 5   complete  3    0.020633
# 4   complete  2    0.019250
# 9     single  3   -0.034134
# 10    single  4   -0.079318
# 11    single  5   -0.146511

# %%
from mlxtend.frequent_patterns import apriori, association_rules
step = 0.05
min_support = 1
min_rules = 20
metric = 'lift'
min_threshold = 1
frequent_itemsets = apriori(one_hot_df, min_support=0.2, use_colnames=True)

# %%
for i in frequent_itemsets['']
# Out:
# Binary Matrix based on Frequent Itemsets:
#        frozenset({'Gender_0'})  frozenset({'Gender_1'})  frozenset({'Age_0'})  \
# 0                            0                        0                     0
# 1                            0                        0                     0
# 2                            0                        0                     0
# 3                            0                        0                     0
# 4                            0                        0                     0
# ...                        ...                      ...                   ...
# 27836                        0                        0                     0
# 27837                        0                        0                     0
# 27838                        0                        0                     0
# 27839                        0                        0                     0
# 27840                        0                        0                     0
#
#        frozenset({'Age_1'})  frozenset({'Age_2'})  frozenset({'Regions_2'})  \
# 0                         0                     0                         0
# 1                         0                     0                         0
# 2                         0                     0                         0
# 3                         0                     0                         0
# 4                         0                     0                         0
# ...                     ...                   ...                       ...
# 27836                     0                     0                         0
# 27837                     0                     0                         0
# 27838                     0                     0                         0
# 27839                     0                     0                         0
# 27840                     0                     0                         0
#
#        frozenset({'Regions_3'})  frozenset({'Cgpa_5'})  frozenset({'Cgpa_6'})  \
# 0                             0                      0                      0
# 1                             0                      0                      0
# 2                             0                      0                      0
# 3                             0                      0                      0
# 4                             0                      0                      0
# ...                         ...                    ...                    ...
# 27836                         0                      0                      0
# 27837                         0                      0                      0
# 27838                         0                      0                      0
# 27839                         0                      0                      0
# 27840                         0                      0                      0
#
#        frozenset({'SleepDuration_0'})  ...  \
# 0                                   0  ...
# 1                                   0  ...
# 2                                   0  ...
# 3                                   0  ...
# 4                                   0  ...
# ...                               ...  ...
# 27836                               0  ...
# 27837                               0  ...
# 27838                               0  ...
# 27839                               0  ...
# 27840                               0  ...
#
#        frozenset({'Gender_1', 'StudyHours_3'})  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 27836                                        0
# 27837                                        0
# 27838                                        0
# 27839                                        0
# 27840                                        0
#
#        frozenset({'FamilyHistoryOfMentalIllness_0', 'Gender_1'})  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 27836                                                  0
# 27837                                                  0
# 27838                                                  0
# 27839                                                  0
# 27840                                                  0
#
#        frozenset({'FamilyHistoryOfMentalIllness_1', 'Gender_1'})  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 27836                                                  0
# 27837                                                  0
# 27838                                                  0
# 27839                                                  0
# 27840                                                  0
#
#        frozenset({'Age_0', 'EducationLevel_0'})  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ...                                         ...
# 27836                                         0
# 27837                                         0
# 27838                                         0
# 27839                                         0
# 27840                                         0
#
#        frozenset({'Age_0', 'FamilyHistoryOfMentalIllness_0'})  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 27836                                                  0
# 27837                                                  0
# 27838                                                  0
# 27839                                                  0
# 27840                                                  0
#
#        frozenset({'Age_0', 'FamilyHistoryOfMentalIllness_1'})  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 27836                                                  0
# 27837                                                  0
# 27838                                                  0
# 27839                                                  0
# 27840                                                  0
#
#        frozenset({'FamilyHistoryOfMentalIllness_0', 'EducationLevel_1'})  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 27836                                                  0
# 27837                                                  0
# 27838                                                  0
# 27839                                                  0
# 27840                                                  0
#
#        frozenset({'FamilyHistoryOfMentalIllness_1', 'EducationLevel_1'})  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 27836                                                  0
# 27837                                                  0
# 27838                                                  0
# 27839                                                  0
# 27840                                                  0
#
#        frozenset({'FamilyHistoryOfMentalIllness_0', 'StudyHours_3'})  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 27836                                                  0
# 27837                                                  0
# 27838                                                  0
# 27839                                                  0
# 27840                                                  0
#
#        frozenset({'FamilyHistoryOfMentalIllness_1', 'StudyHours_3'})
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 27836                                                  0
# 27837                                                  0
# 27838                                                  0
# 27839                                                  0
# 27840                                                  0
#
# [27841 rows x 47 columns]

# %%
# Out:
# Clustering Results:
#       Gender Age Regions Cgpa SleepDuration DietaryHabits EducationLevel  \
# 0          1   2       0    6             1             2              1
# 1          0   0       0    2             1             1              1
# 2          1   2       1    4             0             2              1
# 3          0   1       2    2             2             1              1
# 4          0   1       1    5             1             1              2
# ...      ...  ..     ...  ...           ...           ...            ...
# 27836      0   1       3    2             1             0              0
# 27837      1   1       1    6             0             2              2
# 27838      1   2       1    3             1             0              3
# 27839      0   0       1    3             0             2              0
# 27840      1   1       4    6             0             2              1
#
#       StudyHours FamilyHistoryOfMentalIllness AcademicPressure  \
# 0              1                            0                5
# 1              1                            1                2
# 2              3                            1                3
# 3              1                            1                3
# 4              0                            0                4
# ...          ...                          ...              ...
# 27836          2                            1                5
# 27837          0                            1                2
# 27838          3                            0                3
# 27839          3                            0                5
# 27840          0                            1                4
#
#       StudySatisfaction FinancialStress  Cluster
# 0                     2               1        0
# 1                     5               2        0
# 2                     5               1        0
# 3                     2               5        0
# 4                     3               1        0
# ...                 ...             ...      ...
# 27836                 5               1        0
# 27837                 3               3        0
# 27838                 4               2        0
# 27839                 2               5        0
# 27840                 1               3        0
#
# [27841 rows x 13 columns]
# /opt/anaconda3/envs/venv/lib/python3.13/site-packages/sklearn/base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)

# %%
import matplotlib.pyplot as plt


fig, ax1 = plt.subplots(figsize=(8, 5))

ax1.plot(sil_inertia["k"], sil_inertia["inertia"], marker="o", color="blue", label="Inertia")
ax1.set_xlabel("Number of Clusters")
ax1.set_ylabel("Inertia", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")

ax2 = ax1.twinx()
ax2.plot(sil_inertia["k"], sil_inertia["silhouette"], marker="s", color="red", linestyle="dashed", label="Silhouette Score")
ax2.set_ylabel("Silhouette Score", color="red")
ax2.tick_params(axis="y", labelcolor="red")
ax2.set_ylim(0,1)

fig.suptitle("Elbow Method & Silhouette Score")
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[128], line 6
#       1 import matplotlib.pyplot as plt
#       4 fig, ax1 = plt.subplots(figsize=(8, 5))
# ----> 6 ax1.plot(sil_inertia["k"], sil_inertia["inertia"], marker="o", color="blue", label="Inertia")
#       7 ax1.set_xlabel("Number of Clusters")
#       8 ax1.set_ylabel("Inertia", color="blue")
#
# NameError: name 'sil_inertia' is not defined
